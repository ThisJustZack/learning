# %% [markdown]
# # Assignment 2 Solutions

# %% [markdown]
# # Question 1
#
# Let Z be a standard normal random variable and calculate the following probabilities, drawing pictures whenever appropriate.
#
# (a) P(0 <= Z <= 2.40)
#
# (b) P(0 <= Z <= 1)
#
# (c) P(-2.90 <= Z <= 0)
#
# (d) P(-2.90 <= Z <= 2.9)
#
# (e) P(Z <= 1.14)
#
# (f) P(-1.63 <= Z)
#
# (g) P(-1.9 <= Z <= 2.00)
#
# (h) P(1.14 <= Z <= 2.50)
#
# (i) P(1.9 <= Z)
#
# (j) P( |Z| <= 2.50)

# %%
import scipy.stats as stats

# %%
max = 2.36
min = 0
answerA = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerA)
# Out:
# 0.49086253246942735

# %%
max = 1
min = 0
answerB = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerB)
# Out:
# 0.3413447460685429

# %%
max = 0
min = -2.20
answerC = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerC)
# Out:
# 0.4860965524865014

# %%
max = 2.2
min = -2.20
answerD = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerD)
# Out:
# 0.9721931049730028

# %%
max = -2.5
answerE = stats.norm.cdf(max)
print(answerE)
# Out:
# 0.006209665325776132

# %%
min = -1.43
answerF = 1 - stats.norm.cdf(min)
print(answerF)
# Out:
# 0.9236414904632608

# %%
max = 2.0
min = -1.2
answerG = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerG)
# Out:
# 0.8621801978301126

# %%
max = 2.50
min = 1.56
answerH = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerH)
# Out:
# 0.05317027526901685

# %%
min = 1.2
answerI = 1 - stats.norm.cdf(min)
print(answerI)
# Out:
# 0.11506967022170822

# %%
max = 2.5
min = -2.5
answerJ = stats.norm.cdf(max) - stats.norm.cdf(min)
print(answerJ)
# Out:
# 0.9875806693484477

# %% [markdown]
# # Question 2
#
# Let Z be a standard normal random variable. In each case, determine the value of the constant c that makes the probability statement correct.
#
# (a) Phi(c) = 0.9826
#
# (b) P(0 <= Z <= c) = 0.2995
#
# (c) P(c <= Z) = 0.1251
#
# (d) P(-c <= Z <= c) = 0.6476
#
# (e) P(c <= |Z|) = 0.0139

# %%
z = stats.norm(0, 1)

# %%
answerA = z.ppf(0.9826)
print(answerA)
# Out:
# 2.1106779792322805

# %%
answerB = z.ppf(0.5 + 0.2995)
print(answerB)
# Out:
# 0.8398366163448432

# %%
answerC = z.ppf(0.1314)
print(answerC)
# Out:
# -1.1197976522064033

# %%
answerD = -1 * z.ppf((1 - 0.6476) / 2)
print(answerD)
# Out:
# 0.9299441542460705

# %%
answerE = z.ppf(0.0131 / 2)
print(answerE)
# Out:
# -2.481039106640214

# %% [markdown]
# # Question 3
#
# If X is a normal rv with mean 80 and standard deviation 15, compute the following probabilities by standardizing.
#
# (a) P(X <= 110)
#
# (b) P(X <= 80)
#
# (c) P(57.5 <= X <= 110)
#
# (d) P(65 <= X)
#
# (e) P(87.5 <= X <= 102.5)
#
# (f) P( |X - 80| <= 15)

# %%
x = stats.norm(80, 15)

# %%
answerA = x.cdf(110)
print(answerA)
# Out:
# 0.9772498680518208

# %%
answerB = x.cdf(80)
print(answerB)
# Out:
# 0.5

# %%
answerC = x.cdf(110) - x.cdf(57.5)
print(answerC)
# Out:
# 0.9104426667829627

# %%
answerD = 1 - x.cdf(65)
print(answerD)
# Out:
# 0.8413447460685429

# %%
answerE = x.cdf(102.5) - x.cdf(87.5)
print(answerE)
# Out:
# 0.2417303374571288

# %%
answerF = x.cdf(95) - x.cdf(65)
print(answerF)
# Out:
# 0.6826894921370859

# %% [markdown]
# # Question 4
#
# Suppose the force acting on a column that helps to support a building is normally distributed with mean 15.8 kips and standard deviation 1.33 kips. (Round your answers to four decimal places.)
#
# (a) What is the probability that the force is at most 18 kips?
#
# (b) What is the probability that the force is between 10 and 12 kips?
#
# (c) What is the probability that the force differs from 15.8 kips by at most 1.5 standard deviations?

# %%
mu = 15.6
sigma = 1.34

x = stats.norm(mu, sigma)

# %%
answerA = x.cdf(18)
print(answerA)
# Out:
# 0.9633569450265271

# %%
answerB = x.cdf(12) - x.cdf(10)
print(answerB)
# Out:
# 0.003594888684372948

# %%
answerC = x.cdf(mu + 1.5 * sigma) - x.cdf(mu - 1.5 * sigma)
print(answerC)
# Out:
# 0.8663855974622838

# %% [markdown]
# # Question 5
#
# There are two machines available for cutting corks intended for use in wine bottles. The first produces corks with diameters that are normally distributed with mean 3 cm and standard deviation 0.08 cm. The second machine produces corks with diameters that have a normal distribution with mean 3.04 cm and standard deviation 0.02 cm. Acceptable corks have diameters between 2.9 cm and 3.1 cm.
#
# What is the probability that the first machine produces an acceptable cork? (Round your answer to four decimal places.)
#
# What is the probability that the second machine produces an acceptable cork? (Round your answer to four decimal places.)

# %%
x1 = stats.norm(3.00, 0.08)
x2 = stats.norm(3.04, 0.02)

xlow = 2.9
xhigh = 3.1

# %%
answerA = x1.cdf(xhigh) - x1.cdf(xlow)
print(answerA)
# Out:
# 0.7887004526662897

# %%
answerB = x2.cdf(xhigh) - x2.cdf(xlow)
print(answerB)
# Out:
# 0.99865010196709

# %% [markdown]
# # Question 6
#
# It has been suggested that yield strength (ksi) for A36 grade steel is normally distributed with mu = 45 and σ = 4.0.
#
# (a) What is the probability that yield strength is at most 40?
#
# What is the probability that yield strength is greater than 60?
#
# (b) What yield strength value separates the strongest 75% from the others?

# %%
import scipy.stats as stats

# %%
mu = 45
sigma = 4
x = stats.norm(mu, sigma, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-e54b2c167d85> in <module>()
#       1 mu = 45
#       2 sigma = 4
# ----> 3 x = stats.norm(mu,sigma,0)
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py in __call__(self, *args, **kwds)
#     769
#     770     def __call__(self, *args, **kwds):
# --> 771         return self.freeze(*args, **kwds)
#     772     __call__.__doc__ = freeze.__doc__
#     773
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py in freeze(self, *args, **kwds)
#     766
#     767         """
# --> 768         return rv_frozen(self, *args, **kwds)
#     769
#     770     def __call__(self, *args, **kwds):
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py in __init__(self, dist, *args, **kwds)
#     428         self.dist = dist.__class__(**dist._updated_ctor_param())
#     429
# --> 430         shapes, _, _ = self.dist._parse_args(*args, **kwds)
#     431         self.dist._argcheck(*shapes)
#     432         self.a, self.b = self.dist._get_support(*shapes)
#
# TypeError: _parse_args() takes from 1 to 3 positional arguments but 4 were given

# %%
answerA1 = x.cdf(40)
answerA2 = 1 - x.cdf(60)
print(answerA1)
print(answerA2)
# Out:
# 0.9960582089522081
# 3.5393104003134113e-09

# %%
answerB = x.ppf(0.25)
print(answerB)

# %% [markdown]
# # Question 7
#
# The temperature reading from a thermocouple placed in a constant-temperature medium is normally distributed with mean μ, the actual temperature of the medium, and standard deviation σ. What would the value of σ have to be to ensure that 95% of all readings are within 0.9° of μ?

# %%
centralArea = 0.95
deltaMu = 0.7

# %% [markdown]
# $z = (\bar{x}-\mu)/\sigma$
#
# Therefore,
#
# $\sigma = (\bar{x}-\mu)/z$
#
# $\sigma = \delta_\mu/z$

# %%
xlow = stats.norm.ppf((1-centralArea)/2.0)
xhigh = stats.norm.ppf(centralArea * (1-centralArea) / 2.0)

answer = deltaMu/xhigh
print(answer)
# Out:
# -0.3532116558340337

# %% [markdown]
# # Question 8
#
# Suppose that 10% of all steel shafts produced by a certain process are nonconforming but can be reworked (rather than having to be scrapped). Consider a random sample of 200 shafts, and let X denote the number among these that are nonconforming and can be reworked.
#
# (a) What is the (approximate) probability that X is at most 30?
#
# (b) What is the (approximate) probability that X is less than 30?
#
# (c) What is the (approximate) probability that X is between 15 and 25 (inclusive)?

# %% [markdown]
# This question asks us to make an approximation to a process that is governed (exactly) by the binomial distribution.  The two approximations that we could considers are (a) the normal distribution, and (b) the Poisson distribution.  The normal distribution is appropriate for large N, and p $\approx$ 0.5.  The Poission distribution is appropriate for small p or large p.  Since we have p = 0.10, we choose the Poisson distribution.

# %%
import numpy as np
import scipy.stats as stats
n = 200
p = 0.1

# %%
lmbda = n*p
x = stats.poisson(lmbda)

answerA = x.cdf(30.5)
answerB = x.cdf(29.5)
answerC = x.cdf(25.5) - x.cdf(14.5)
print(answerA)
print(answerB)
print(answerC)
# Out:
# 0.8134474276130004
# 0.7592618340986071
# 0.46629866267346864

# %%
lmbda = n*p
x = stats.poisson(lmbda)

answerA = x.cdf(30)
answerB = x.cdf(29)
answerC = x.cdf(25) - x.cdf(14)
print(answerA)
print(answerB)
print(answerC)
# Out:
# 0.8134474276130004
# 0.7592618340986071
# 0.46629866267346864

# %%
x = stats.binom(n, p)

answerA = x.cdf(30)
answerB = x.cdf(29)
answerC = x.cdf(25) - x.cdf(14)
print(answerA)
print(answerB)
print(answerC)
# Out:
# 0.828853732023124
# 0.7727463397020421
# 0.4634823428830051

# %%
x = stats.norm(n*p, np.sqrt(n*p*(1-p)))

answerA = x.cdf(30.5)
answerB = x.cdf(29.5)
answerC = x.cdf(25.5) - x.cdf(14.5)
print(answerA)
print(answerB)
print(answerC)
# Out:
# 0.9933358356095913
# 0.9874276194133214
# 0.7614071706835643

# %%
lmbda = n*p
x = stats.gamma(lmbda)

answerA = x.cdf(30.5)
answerB = x.cdf(29.5)
answerC = x.cdf(25.5) - x.cdf(14.5)
print(answerA)
print(answerB)
print(answerC)
